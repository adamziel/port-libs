# %% [markdown]
# # Notebook import
#
# Review **bold** markdown with [source](https://example.test/notebook).

# %%
total = 2 + 2
print("ready")
# Out:
# ready\n

# %% [raw]
# ---
# title: Source notebook
# ---

# %% [markdown]
# - [x] preserve cells
# - [ ] review outputs
